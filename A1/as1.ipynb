# %% [markdown]
# # Assignment 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Jiawei Luo
#
# Student ID: 1114028

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Sunday, 27 March 2022 5pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -10% per day (both week and weekend days counted)
#
# <b>Marks</b>: 9% of mark for class (with 8% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See "Using Jupyter Notebook and Python" page on Canvas (under Modules>Resources) for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, and Gensim. We recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks. <b> You should use Python 3</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=https://www.nltk.org/book/>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each question is worth is explicitly given.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection of tweets. The task is to predict the geolocation (country) where the tweet comes from. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # Preprocessing (4 marks)

# %% [markdown]
# **Instructions**: Download the data (as1-data.json) from Canvas and put it in the same directory as this iPython notebook. Run the code below to load the json data. This produces two objects, `x` and `y`, which contains a list of  tweets and corresponding country labels (it uses the standard [2 letter country code](https://www.iban.com/country-codes)) respectively. **No implementation is needed.**

# %%
import json

x = []
y = []
data = json.load(open("as1-data.json"))
for k, v in data.items():
    x.append(k)
    y.append(v)
    
print("Number of tweets =", len(x))
print("Number of labels =", len(y))
print("\nSamples of data:")
for i in range(10):
    print("Country =", y[i], "\tTweet =", x[i])
    
assert(len(x) == 943)
assert(len(y) == 943)
# Out:
# Number of tweets = 943
# Number of labels = 943
#
# Samples of data:
# Country = us 	Tweet = @Addictd2Success thx u for following
# Country = us 	Tweet = Let's just say, if I were to ever switch teams, Khalesi would be top of the list. #girlcrush
# Country = ph 	Tweet = Taemin jonghyun!!! Your birits make me go~ http://t.co/le8z3dntlA
# Country = id 	Tweet = depart.senior 👻 rapat perdana (with Nyayu, Anita, and 8 others at Ruang Aescullap FK Unsri Madang) — https://t.co/swRALlNkrQ
# Country = ph 	Tweet = Done with internship with this pretty little lady!  (@ Metropolitan Medical Center w/ 3 others) [pic]: http://t.co/1qH61R1t5r
# Country = gb 	Tweet = Wow just Boruc's clanger! Haha Sunday League stuff that, Giroud couldn't believe his luck! #clown
# Country = my 	Tweet = I'm at Sushi Zanmai (Petaling Jaya, Selangor) w/ 5 others http://t.co/bcNobykZ
# Country = us 	Tweet = Mega Fest!!!! Its going down🙏🙌  @BishopJakes
# Country = gb 	Tweet = @EllexxxPharrell wow love the pic babe xx
# Country = us 	Tweet = You have no clue how much you hurt me

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation (based on frequency). The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); (2) lowercase all words; (3) remove any word that does not contain any English alphabets (e.g. {_hello_, _#okay_, _abc123_} would be kept, but not {_123_, _!!_}) and (4) remove stopwords (based on NLTK `stopwords`). An empty tweet (after preprocessing) and its country label should be **excluded** from the output (`x_processed` and `y_processed`).
#
# **Task**: Complete the `preprocess_data(data, labels)` function. The function takes **a list of tweets** and **a corresponding list of country labels** as input, and returns **two lists**. For the first list, each element is a bag-of-words representation of a tweet (represented using a python dictionary). For the second list, each element is a corresponding country label. Note that while we do not need to preprocess the country labels (`y`), we need to have a new output list (`y_processed`) because some tweets maybe removed after the preprocessing (due to having an empty set of bag-of-words).
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords

tt = TweetTokenizer()
stopwords = set(stopwords.words('english')) #note: stopwords are all in lowercase

def preprocess_data(data, labels):
    
    ###
    # Your answer BEGINS HERE
    ###
    
    tweets = []
    for tweet in data:
        # (1) tokenize each tweet into individual word tokens (using NLTK TweetTokenizer);
        # (2) lowercase all words;
        tweets.append(tt.tokenize(tweet.lower()))
    # (3) remove any word that does not contain any English alphabets
    tokenlist_alp = []
    bag_of_words = {}
    labels_processed = labels
    for tweet in tweets:
        temp = []
        for word in tweet:
            token_alp = "".join(filter(str.isalpha,word))
            # (4) remove stopwords
            if len(token_alp)>0 and word not in stopwords:
                temp.append(word)
        if len(temp)==0:
            tweet_index = tweets.index(tweet)
            del labels_processed[tweet_index]
        else:
            bag_of_words = {word : temp.count(word) for word in set(temp)}
            tokenlist_alp.append(bag_of_words)

    return tokenlist_alp, labels_processed
    

    ###
    # Your answer ENDS HERE
    ###

x_processed, y_processed = preprocess_data(x, y)

print("Number of preprocessed tweets =", len(x_processed))
print("Number of preprocessed labels =", len(y_processed))
print("\nSamples of preprocessed data:")
for i in range(10):
    print("Country =", y_processed[i], "\tTweet =", x_processed[i])
# Out:
# Number of preprocessed tweets = 943
# Number of preprocessed labels = 943
#
# Samples of preprocessed data:
# Country = us 	Tweet = {'following': 1, '@addictd2success': 1, 'u': 1, 'thx': 1}
# Country = us 	Tweet = {'list': 1, 'khalesi': 1, 'say': 1, 'top': 1, '#girlcrush': 1, 'ever': 1, 'teams': 1, 'would': 1, "let's": 1, 'switch': 1}
# Country = ph 	Tweet = {'taemin': 1, 'make': 1, 'http://t.co/le8z3dntla': 1, 'go': 1, 'birits': 1, 'jonghyun': 1}
# Country = id 	Tweet = {'ruang': 1, 'aescullap': 1, 'unsri': 1, 'anita': 1, 'fk': 1, 'nyayu': 1, 'depart.senior': 1, 'others': 1, 'madang': 1, 'https://t.co/swrallnkrq': 1, 'rapat': 1, 'perdana': 1}
# Country = ph 	Tweet = {'done': 1, 'center': 1, 'pretty': 1, 'pic': 1, 'metropolitan': 1, 'internship': 1, 'medical': 1, 'others': 1, 'little': 1, 'lady': 1, 'http://t.co/1qh61r1t5r': 1, 'w': 1}
# Country = gb 	Tweet = {'believe': 1, 'wow': 1, 'clanger': 1, 'stuff': 1, "boruc's": 1, 'sunday': 1, 'giroud': 1, 'luck': 1, 'haha': 1, '#clown': 1, 'league': 1}
# Country = my 	Tweet = {'selangor': 1, 'petaling': 1, "i'm": 1, 'zanmai': 1, 'jaya': 1, 'others': 1, 'http://t.co/bcnobykz': 1, 'w': 1, 'sushi': 1}
# Country = us 	Tweet = {'mega': 1, '@bishopjakes': 1, 'going': 1, 'fest': 1}
# Country = gb 	Tweet = {'pic': 1, 'xx': 1, '@ellexxxpharrell': 1, 'wow': 1, 'babe': 1, 'love': 1}
# Country = us 	Tweet = {'clue': 1, 'much': 1, 'hurt': 1}

# %% [markdown]
# **For your testing**:

# %%
assert(len(x_processed) == len(y_processed))
assert(len(x_processed) > 800)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(data):
    hashtags = set([])
    for d in data:
        for word, frequency in d.items():
            if word.startswith("#") and len(word) > 1:
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(x_processed)
print("Number of hashtags =", len(hashtags))
print(sorted(hashtags))
# Out:
# Number of hashtags = 425
# ['#100percentpay', '#1stsundayofoctober', '#1yearofalmostisneverenough', '#2011prdctn', '#2015eebritishfilmacademyawards', '#2k16', '#2littlebirds', '#365picture', '#5sosacousticatlanta', '#5sosfam', '#8thannualpubcrawl', '#affsuzukicup', '#aflpowertigers', '#ahimacon14', '#aim20', '#airasia', '#allcity', '#alliswell', '#allwedoiscurls', '#amazing', '#anferneehardaway', '#ariona', '#art', '#arte', '#artwork', '#ashes', '#asian', '#asiangirl', '#askcrawford', '#askherforfback', '#askolly', '#asksteven', '#at', '#australia', '#awesome', '#awesomepict', '#barcelona', '#bart', '#bayofislands', '#beautiful', '#bedimages', '#bell', '#beringmy', '#bettybooppose', '#bff', '#big', '#bigbertha', '#bigbreakfast', '#blackhat', '#blessedmorethanicanimagine', '#blessedsunday', '#blogtourambiente', '#bluemountains', '#bonekachika', '#boomtaob', '#booyaa', '#bored', '#boredom', '#bradersisterhood', '#breaktime', '#breedingground', '#bringithomemy', '#brooksengland', '#burgers', '#butitsalsokindofaphone', '#bye', '#camera', '#canadaelections', '#cbb', '#cbcolympics', '#cctv', '#cdnpoli', '#celebritycrush', '#chargers', '#chocolate', '#ciosummit', '#cleansidewalk', '#clown', '#coffeespoonart', '#colts', '#confused', '#cornell', '#country', '#craftbeer', '#creative', '#crepes', '#cumannanya', '#danny4mayor', '#data', '#date', '#datingsiteforyou', '#dearmind', '#deed', '#delightful', '#dennisrodman', '#design', '#devacurl', '#die', '#difd', '#diner', '#dinner', '#dragoncon', '#dus', '#dynamounlock', '#earrings', '#eeeeeehhh', '#election2015', '#electriccircus2014', '#endomondo', '#engine', '#english', '#europapark', '#excitables', '#fabulous', '#factorycampus', '#fall', '#familydinner', '#ff', '#fire', '#flambees', '#flashback', '#fly', '#focusateneo', '#followher', '#followme', '#foodporn', '#fotografías', '#fotorus', '#four', '#freaks', '#friday', '#fridaynight', '#fried', '#friends', '#friendshipflow', '#fries', '#frozenyoghurt', '#fun', '#future', '#galaxy', '#getfreetattooaviciipasses', '#girl', '#girlcrush', '#girls', '#givesmehope', '#goingout', '#google', '#graduated', '#grafunkthiremepls', '#grammyfans', '#grandmarnier', '#greenfood', '#grilled', '#gudnytall', '#gunner', '#gym', '#handbuiltbicycle', '#happybirthdaysandarapark', '#happyfriday', '#harimaumalaya', '#hb60', '#hens', '#hippy', '#holiday', '#hollywoodmusicawards', '#homemadegranola', '#hometomama', '#hot', '#hungergames', '#hungry', '#icu', '#ididntchoosethestudentlifeitchoseme', '#iloveyou', '#imsobored', '#imsosore', '#innoretail', '#insanity', '#insightmedia', '#insightmediasingapore', '#instaframeplus', '#instagood', '#instalook', '#isibaya', '#javaboy', '#jed', '#jewelry', '#jo', '#jordaan', '#jrsurfboards', '#justshare', '#kllive', '#ladygaga', '#latepost', '#laugh', '#laundryservice', '#lazysunday', '#learningcommunties', '#lebedeintennis', '#letmesleep', '#lfc', '#lgbt', '#life', '#lipstickfree', '#littlemonsters', '#loadsoffun', '#lol', '#longranger', '#lotsoflove', '#love', '#lovers', '#lovethisgirl', '#lovevibes', '#lte', '#magazinesandtvscreens', '#magic', '#makeupfree', '#makingemuklajawabnya', '#mamajeanneandme', '#mancrush', '#march', '#massacreconspiracy', '#mauce', '#mavic', '#me', '#meetup', '#melbourne', '#michaelkors', '#mindfulness', '#mkmedi', '#mobile', '#morning', '#mountains', '#movies', '#mtlnewtech', '#mtvhottest', '#mushroom', '#music', '#mustfollow', '#mwc14', '#mybabyemilia', '#myfriendsarebetterthanyours', '#nced', '#ncga', '#ncpol', '#nevergetsold', '#new', '#newlooks', '#newrecord', '#nextlevel', '#nfl', '#nickryrie', '#nochillzone', '#nofilter', '#notersnew2014', '#notreally', '#np', '#nye', '#of', '#offtochurch', '#ohyeah', '#oilandgas', '#olah', '#on', '#oops', '#openspace', '#oscars', '#oui', '#palacefansinthemorning', '#panther', '#panthers', '#partyhardpartyy', '#pats', '#pechanga', '#penny', '#peperoni', '#peppermoney', '#photo', '#photoby', '#photography', '#pic', '#pll', '#pmattheashes', '#pop-up', '#positivity', '#potd', '#procrastina ...

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing the **MaxMatch algorithm** discussed in class.
#
# NLTK has a list of words that you can use for matching, see starter code below (`words`). Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words (`words`) includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching (provided by the function `lemmatize(word)`). Note that the list of words (`words`) is the only source that you'll use for matching (i.e. you do not need to find  other external word lists). If you are unable to make any longer match, your code should default to matching a single letter.
#
# For example, given "#newrecord", the algorithm should produce: \["#", "new", "record"\].
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
from nltk.corpus import wordnet

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words())  # a list of words provided by NLTK
# lowercase all the words for better matching
words = set([word.lower() for word in words])


def lemmatize(word):
    lemma = lemmatizer.lemmatize(word, 'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word, 'n')
    return lemma


def tokenize_hashtags(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    tag_dict = {}
    for hashtag in hashtags:
        tokens = []
        i = 0
        len_tags = len(hashtag)
        j = len_tags
        while i < len_tags:
            while i < j:
                temp_word = hashtag[i:j]
                lemma = lemmatize(temp_word)
                if lemma in words or not (j > i + 1):
                    tokens.append(temp_word)
                    i = j
                    j = len_tags
                else:
                    j = j - 1

        tag_dict[hashtag] = tokens
    return tag_dict

    ###
    # Your answer ENDS HERE
    ###


# tokenise hashtags with MaxMatch
tokenized_hashtags = tokenize_hashtags(hashtags)

# print results
for k, v in sorted(tokenized_hashtags.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'vega', 'n']
# #veganfood ['#', 'vega', 'n', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'coca', 'm']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'wear', 'e', '9', '0', 's']
# #wearesocial ['#', 'weares', 'o', 'c', 'i', 'al']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'wo', 'k']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'ama', 's']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))
assert(tokenized_hashtags["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 3 (1.0 mark)
#
# **Instructions**: Our next task is to tokenize the hashtags again, but this time using a **reversed version of the MaxMatch algorithm**, where matching begins at the end of the hashtag and progresses backwards (e.g. for <i>#helloworld</i>, we would process it right to left, starting from the last character <i>d</i>). Just like before, you should use the provided word list (`words`) for word matching.
#
# **Task**: Complete the `tokenize_hashtags_rev(hashtags)` function by the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
def tokenize_hashtags_rev(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    tag_dict = {}
    for hashtag in hashtags:
        tokens = []
        i = 0
        len_tags = len(hashtag)
        j = len_tags
        while j > 0:
            i = 0
            while i < j:
                temp_word = hashtag[i:j]
                lemma = lemmatize(temp_word)
                if lemma in words or not (j > i + 1):
                    tokens.append(temp_word)
                    j = i
                    i = 0
                else:
                    i = i + 1
        tokens.reverse()
        tag_dict[hashtag] = tokens
    return tag_dict
    

    ###
    # Your answer ENDS HERE
    ###

    
#tokenise hashtags with the reversed version of MaxMatch
tokenized_hashtags_rev = tokenize_hashtags_rev(hashtags)

#print results
for k, v in sorted(tokenized_hashtags_rev.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'v', 'e', 'gan']
# #veganfood ['#', 'v', 'e', 'gan', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'c', 'o', 'cam']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'we', 'are', '9', '0', 's']
# #wearesocial ['#', 'we', 'are', 'social']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'w', 'ok']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'a', 'mas']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags_rev) == len(hashtags))
assert(tokenized_hashtags_rev["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: The two versions of MaxMatch will produce different results for some of the hashtags. For a hastag that has different results, our task here is to use a **unigram language model** (lecture 3) to score them to see which is better. Recall that in a unigram language model we compute P(<i>#</i>, <i>hello</i>, <i>world</i> = P(<i>#</i>)\*P(<i>hellow</i>)\*P(<i>world</i>).
#
# You should: (1) use the NLTK's Brown corpus (`brown_words`) for collecting word frequencies (note: the words are already tokenised so no further tokenisation is needed); (2) lowercase all words in the corpus; (3) use add-one smoothing when computing the unigram probabilities; and (4) work in the log space to prevent numerical underflow.
#
# **Task**: Build a unigram language model with add-one smoothing using the word counts from the Brown corpus. Iterate through the hashtags, and for each hashtag where MaxMatch and reversed MaxMatch produce different results, print the following: (1) the hashtag; (2) the results produced by MaxMatch and reversed MaxMatch; and (3) the log probability of each result as given by the unigram language model. Note: you **do not** need to print the hashtags where MaxMatch and reversed MaxMatch produce the same results.
#
# An example output:
# ```
# 1. #abcd
# MaxMatch = [#, a, bc, d]; LogProb = -2.3
# Reversed MaxMatch = [#, a, b, cd]; LogProb = -3.5
#
# 2. #efgh
# MaxMatch = [#, ef, g, h]; LogProb = -4.2
# Reversed MaxMatch = [#, e, fgh]; LogProb = -3.1
#
# ```
#
# Have a look at the output, and see if the sequences with better language model scores (i.e. less negative) are generally more coherent.

# %%
from nltk.corpus import brown
import math
#words from brown corpus
brown_words = brown.words()

###
# Your answer BEGINS HERE
###
# (1) use the NLTK's Brown corpus (`brown_words`) 
# for collecting word frequencies 
# get whole word count 
len_b_words = len(brown_words)
# (2) lowercase all words in the corpus; 
brown_words_lower = [word.lower() for word in brown_words]
# get lower word distinct count
len_b_words_distinct_lower = len(set(brown_words_lower))
# create word library
library_dict = {}
for b_word in brown_words:
    b_word = b_word.lower()
    if b_word not in library_dict:
        library_dict[b_word] = 1
    else:
        library_dict[b_word] += 1

# (3) use add-one smoothing when computing the unigram probabilities; 
# (4) work in the log space to prevent numerical underflow.

n_count = 0
# maxmatch: tokenized_hashtags    
# reversed maxmatch: tokenized_hashtags_rev
for hashtag in hashtags:
    # check maxmatch and reversed maxmatch
    tok_tag = tokenized_hashtags[hashtag]
    tok_tag_rev = tokenized_hashtags_rev[hashtag]
    if tok_tag != tok_tag_rev:
        # get index 
        n_count += 1
        print(str(n_count)+'. '+ hashtag)
        # calculate unigram probs
        tok_tag_prob, tok_tag_rev_prob = 0.0, 0.0
        for word in tok_tag:
            if word in library_dict:
                tok_tag_prob += math.log((library_dict[word] + 1) / (len_b_words + len_b_words_distinct_lower))
            else:
                tok_tag_prob += math.log(1 / (len_b_words + len_b_words_distinct_lower))
        print("MaxMatch = "+ str(tok_tag) + "; LogProb = "+ str(tok_tag_prob))

        for word in tok_tag_rev:
            if word in library_dict:
                tok_tag_rev_prob += math.log((library_dict[word] + 1) / (len_b_words + len_b_words_distinct_lower))
            else:
                tok_tag_rev_prob += math.log(1 / (len_b_words + len_b_words_distinct_lower))
        print("Reversed MaxMatch = "+ str(tok_tag) + "; LogProb = "+ str(tok_tag_rev_prob) + '\n')




    
###
# Your answer ENDS HERE
###
# Out:
# 1. #letmesleep
# MaxMatch = ['#', 'let', 'mes', 'leep']; LogProb = -50.07460787717359
# Reversed MaxMatch = ['#', 'let', 'mes', 'leep']; LogProb = -38.80998993718112
#
# 2. #imsobored
# MaxMatch = ['#', 'i', 'ms', 'o', 'bored']; LogProb = -54.38265427699833
# Reversed MaxMatch = ['#', 'i', 'ms', 'o', 'bored']; LogProb = -48.35001224300944
#
# 3. #uniexamonasaturday
# MaxMatch = ['#', 'unie', 'x', 'am', 'ona', 'saturday']; LogProb = -71.5774097161047
# Reversed MaxMatch = ['#', 'unie', 'x', 'am', 'ona', 'saturday']; LogProb = -80.03982716760159
#
# 4. #thankyoulord
# MaxMatch = ['#', 'thank', 'youl', 'or', 'd']; LogProb = -54.147565385367656
# Reversed MaxMatch = ['#', 'thank', 'youl', 'or', 'd']; LogProb = -39.77590794288293
#
# 5. #focusateneo
# MaxMatch = ['#', 'focus', 'aten', 'e', 'o']; LogProb = -59.31183301491378
# Reversed MaxMatch = ['#', 'focus', 'aten', 'e', 'o']; LogProb = -76.59869844284354
#
# 6. #nevergetsold
# MaxMatch = ['#', 'never', 'gets', 'old']; LogProb = -38.77967393337103
# Reversed MaxMatch = ['#', 'never', 'gets', 'old']; LogProb = -38.98835789126076
#
# 7. #weare90s
# MaxMatch = ['#', 'wear', 'e', '9', '0', 's']; LogProb = -66.33056265378181
# Reversed MaxMatch = ['#', 'wear', 'e', '9', '0', 's']; LogProb = -57.35598449468522
#
# 8. #fotografías
# MaxMatch = ['#', 'fot', 'og', 'ra', 'f', 'í', 'as']; LogProb = -84.85536620701038
# Reversed MaxMatch = ['#', 'fot', 'og', 'ra', 'f', 'í', 'as']; LogProb = -81.93759547492611
#
# 9. #coffeespoonart
# MaxMatch = ['#', 'coffees', 'poon', 'art']; LogProb = -50.68551695949656
# Reversed MaxMatch = ['#', 'coffees', 'poon', 'art']; LogProb = -44.370158957974226
#
# 10. #wearesocial
# MaxMatch = ['#', 'weares', 'o', 'c', 'i', 'al']; LogProb = -64.13416198687925
# Reversed MaxMatch = ['#', 'weares', 'o', 'c', 'i', 'al']; LogProb = -33.81338267207766
#
# 11. #insightmediasingapore
# MaxMatch = ['#', 'insight', 'media', 'sing', 'a', 'pore']; LogProb = -63.5615297924938
# Reversed MaxMatch = ['#', 'insight', 'media', 'sing', 'a', 'pore']; LogProb = -74.71486738172212
#
# 12. #getfreetattooaviciipasses
# MaxMatch = ['#', 'get', 'freet', 'at', 'too', 'a', 'vic', 'i', 'i', 'passes']; LogProb = -86.0402830918303
# Reversed MaxMatch = ['#', 'get', 'freet', 'at', 'too', 'a', 'vic', 'i', 'i', 'passes']; LogProb = -81.7892120735291
#
# 13. #butitsalsokindofaphone
# MaxMatch = ['#', 'but', 'its', 'also', 'kind', 'of', 'a', 'phone']; LogProb = -58.856091554731236
# Reversed MaxMatch = ['#', 'but', 'its', 'also', 'kind', 'of', 'a', 'phone']; LogProb = -91.65755389449471
#
# 14. #skullsearcher
# MaxMatch = ['#', 'skulls', 'ear', 'che', 'r']; LogProb = -61.178295517306864
# Reversed MaxMatch = ['#', 'skulls', 'ear', 'che', 'r']; LogProb = -40.63459404747614
#
# 15. #yiamas
# MaxMatch = ['#', 'y', 'i', 'ama', 's']; LogProb = -55.86475276705583
# Reversed MaxMatch = ['#', 'y', 'i', 'ama', 's']; LogProb = -49.641659034548596
#
# 16. #instalook
# MaxMatch = ['#', 'ins', 'tal', 'o', 'ok']; LogProb = -64.94721767909434
# Reversed MaxMatch = ['#', 'ins', 'tal', 'o', 'ok']; LogProb = -50.03638666435339
#
# 17. #siberuang
# MaxMatch = ['#', 'sib', 'er', 'uang']; LogProb = -56.027851211461375
# Reversed MaxMatch = ['#', 'sib', 'er', 'uang']; LogProb = -55.334704030901435
#
# 18. #burgers
# MaxMatch = ['#', 'burg', 'ers']; LogProb = -42.02088840859603
# Reversed MaxMatch = ['#', 'burg', 'ers']; LogProb = -42.02088840859603
#
# 19. #ritenow
# MaxMatch = ['#', 'rite', 'now']; LogProb = -32.64207188664795
# Reversed MaxMatch = ['#', 'rite', 'now']; LogProb = -42.02088840859603
#
# 20. #samsung
# MaxMatch = ['#', 'sams', 'un', 'g']; LogProb = -50.5555805377899
# Reversed MaxMatch = ['#', 'sams', 'un', 'g']; LogProb = -34.69442279475571
#
# 21. #grammyfans
# MaxMatch = ['#', 'gram', 'my', 'fans']; LogProb = -43.354284332587376
# Reversed MaxMatch = ['#', 'gram', 'my', 'fans']; LogProb = -50.10359541404684
#
# 22. #cleansidewalk
# MaxMatch = ['#', 'cleans', 'ide', 'walk']; LogProb = -50.719583514060176
# Reversed MaxMatch = ['#', 'cleans', 'ide', 'walk']; LogProb = -34.68135071318836
#
# 23. #melbourne
# MaxMatch = ['#', 'mel', 'bourn', 'e']; LogProb = -49.423907386860904
# Reversed MaxMatch = ['#', 'mel', 'bourn', 'e']; LogProb = -58.12239456631912
#
# 24. #swedumtl
# MaxMatch = ['#', 's', 'wed', 'um', 't', 'l']; LogProb = -71.0083102294149
# Reversed MaxMatch = ['#', 's', 'wed', 'um', 't', 'l']; LogProb = -65.83291407637937
#
# 25. #photoby
# MaxMatch = ['#', 'photo', 'by']; LogProb = -31.652346956540082
# Reversed MaxMatch = ['#', 'photo', 'by']; LogProb = -42.02088840859603
#
# 26. #cbcolympics
# MaxMatch = ['#', 'c', 'b', 'coly', 'm', 'pics']; LogProb = -71.74110333429053
# Reversed MaxMatch = ['#', 'c', 'b', 'coly', 'm', 'pics']; LogProb = -74.57431667834675
#
# 27. #thenext5goldenyears
# MaxMatch = ['#', 'then', 'ex', 't', '5', 'golden', 'years']; LogProb = -69.78129654279155
# Reversed MaxMatch = ['#', 'then', 'ex', 't', '5', 'golden', 'years']; LogProb = -51.32548180278193
#
# 28. #difd
# MaxMatch = ['#', 'di', 'f', 'd']; LogProb = -45.34961345016367
# Reversed MaxMatch = ['#', 'di', 'f', 'd']; LogProb = -40.46844195545796
#
# 29. #openspace
# MaxMatch = ['#', 'opens', 'pace']; LogProb = -35.40348543062156
# Reversed MaxMatch = ['#', 'opens', 'pace']; LogProb = -31.03534148073286
#
# 30. #txlege
# MaxMatch = ['#', 't', 'x', 'leg', 'e']; LogProb = -55.11440695478732
# Reversed MaxMatch = ['#', 't', 'x', 'leg', 'e']; LogProb = -69.26708156883406
#
# 31. #foodporn
# MaxMatch = ['#', 'food', 'po', 'r', 'n']; LogProb = -57.01733126774336
# Reversed MaxMatch = ['#', 'food', 'po', 'r', 'n']; LogProb = -48.68572958898875
#
# 32. #jordaan
# MaxMatch = ['#', 'jo', 'r', 'da', 'an']; LogProb = -53.42564526255384
# Reversed MaxMatch = ['#', 'jo', 'r', 'da', 'an']; LogProb = -48.74470182509296
#
# 33. #myfriendsarebetterthanyours
# MaxMatch = ['#', 'my', 'friends', 'are', 'better', 'than', 'yours']; LogProb = -60.60523299610116
# Reversed MaxMatch = ['#', 'my', 'friends', 'are', 'better', 'than', 'yours']; LogProb = -69.18936620707629
#
# 34. #imsosore
# MaxMatch = ['#', 'i', 'ms', 'os', 'ore']; LogProb = -59.69339416354492
# Reversed MaxMatch = ['#', 'i', 'ms', 'os', 'ore']; LogProb = -48.660167171313276
#
# 35. #bringithomemy
# MaxMatch = ['#', 'bring', 'it', 'home', 'my']; LogProb = -42.3969400397748
# Reversed MaxMatch = ['#', 'bring', 'it', 'home', 'my']; LogProb = -54.934471662227295
#
# 36. #ahimacon14
# MaxMatch = ['#', 'ah', 'ima', 'con', '1', '4']; LogProb = -67.22502598261144
# Reversed MaxMatch = ['#', 'ah', 'ima', 'con', '1', '4']; LogProb = -58.83287854973469
#
# 37. #oilandgas
# MaxMatch = ['#', 'oil', 'and', 'gas']; LogProb = -36.58832892349973
# Reversed MaxMatch = ['#', 'oil', 'and', 'gas']; LogProb = -48.19507485096406
#
# 38. #alliswell
# MaxMatch = ['#', 'all', 'is', 'well']; LogProb = -31.999366818951252
# Reversed MaxMatch = ['#', 'all', 'is', 'well']; LogProb = -50.690313131760064
#
# 39. #usydhereicome
# MaxMatch = ['#', 'us', 'y', 'd', 'here', 'i', 'come']; LogProb = -64.19058954620297
# Reversed MaxMatch = ['#', 'us', 'y', 'd', 'here', 'i', 'come']; LogProb = -59.78434759171772
#
# 40. #cdnpoli
# MaxMatch = ['#', 'c', 'd', 'n', 'pol', 'i']; LogProb = -63.09270811205109
# Reversed MaxMatch = ['#', 'c', 'd', 'n', 'pol', 'i']; LogProb = -70.94922131304489
#
# 41. #learningcommunties
# MaxMatch = ['#', 'learning', 'c', 'om', 'munt', 'ies']; LogProb = -75.1268819082855
# Reversed MaxMatch = ['#', 'learning', 'c', 'om', 'munt', 'ies']; LogProb = -72.29366856422928
#
# 42. #thewalkingdead
# MaxMatch = ['#', 'thew', 'alk', 'ing', 'dead']; LogProb = -64.8700280404032
# Reversed MaxMatch = ['#', 'thew', 'alk', 'ing', 'dead']; LogProb = -35.69988161129523
#
# 43. #reachingyougpeople
# MaxMatch = ['#', 'reaching', 'you', 'g', 'people']; LogProb = -48.576799826896114
# Reversed MaxMatch = ['#', 'reaching', 'you', 'g', 'people']; LogProb = -59.507743744616555
#
# 44. #askolly
# MaxMatch = ['#', 'ask', 'o', 'l', 'ly']; LogProb = -59.0459513999045
# Reversed MaxMatch = ['#', 'ask', 'o', 'l', 'ly']; LogProb = -47.13854289161853
#
# 45. #bradersisterhood
# MaxMatch = ['#', 'brad', 'ers', 'ist', 'er', 'hood']; LogProb = -80.57604091439234
# Reversed MaxMatch = ['#', 'brad', 'ers', 'ist', 'er', 'hood']; LogProb = -55.334704030901435
#
# 46. #longranger
# MaxMatch = ['#', 'long', 'ranger']; LogProb = -34.298210892128026
# Reversed MaxMatch = ['#', 'long', 'ranger']; LogProb = -44.378525971611154
#
# 47. #wok
# MaxMatch = ['#', 'wo', 'k']; LogProb = -39.62299313579766
# Reversed MaxMatch = ['#', 'wo', 'k']; LogProb = -38.43736947013992
#
# 48. #endomondo
# MaxMatch = ['#', 'end', 'om', 'on', 'do']; LogProb = -47.98436812043095
# Reversed MaxMatch = ['#', 'end', 'om', 'on', 'do']; LogProb = -52.82587161528012
#
# 49. #harimaumalaya
# MaxMatch = ['#', 'ha', 'rima', 'um', 'ala', 'ya']; LogProb = -79.72428870365574
# Reversed MaxMatch = ['#', 'ha', 'rima', 'um', 'ala', 'ya']; LogProb = -84.71158749572162
#
# 50. #lebedeintennis
# MaxMatch = ['#', 'l', 'e', 'bed', 'e', 'in', 'tennis']; LogProb = -70.19551835668177
# Reversed MaxMatch = ['#', 'l', 'e', 'bed', 'e', 'in', 'tennis']; LogProb = -65.18832648436327
#
# 51. #asksteven
# MaxMatch = ['#', 'asks', 'te', 'v', 'en']; LogProb = -61.678728983305234
# Reversed MaxMatch = ['#', 'asks', 'te', 'v', 'en']; LogProb = -37.16107600423436
#
# 52. #vscocam
# MaxMatch = ['#', 'vs', 'coca', 'm']; LogProb = -51.58519995497106
# Reversed MaxMatch = ['#', 'vs', 'coca', 'm']; LogProb = -59.63237101059509
#
# 53. #affsuzukicup
# MaxMatch = ['#', 'a', 'f', 'fs', 'u', 'z', 'u', 'k', 'i', 'cup']; LogProb = -104.56090380771312
# Reversed MaxMatch = ['#', 'a', 'f', 'fs', 'u', 'z', 'u', 'k', 'i', 'cup']; LogProb = -91.37383989104686
#
# 54. #startupfest
# MaxMatch = ['#', 'start', 'up', 'fest']; LogProb = -43.43956502588367
# Reversed MaxMatch = ['#', 'start', 'up', 'fest']; LogProb = -52.7697546734399
#
# 55. #nced
# MaxMatch = ['#', 'n', 'ce', 'd']; LogProb = -48.432463932607405
# Reversed MaxMatch = ['#', 'n', 'ce', 'd']; LogProb = -44.92121119098321
#
# 56. #scifigeek
# MaxMatch = ['#', 's', 'c', 'if', 'i', 'geek']; LogProb = -59.85684318442116
# Reversed MaxMatch = ['#', 's', 'c', 'if', 'i', 'geek']; LogProb = -67.55260117497592
#
# 57. #ciosummit
# MaxMatch = ['#', 'c', 'ios', 'um', 'mi', 't']; LogProb = -71.88531467221522
# Reversed MaxMatch = ['#', 'c', 'ios', 'um', 'mi', 't']; LogProb = -47.96573362870664
#
# 58. #blackhat
# MaxMatch = ['#', 'black', 'hat']; LogProb = -32.65971714691727
# Reversed MaxMatch = ['#', 'black', 'hat']; LogProb = -51.36441211734931
#
# 59. #socal
# MaxMatch = ['#', 'soc', 'al']; LogProb = -38.762791870574546
# Reversed MaxMatch = ['#', 'soc', 'al']; LogProb = -33.73386338343097
#
# 60. #pmattheashes
# MaxMatch = ['#', 'p', 'matt', 'he', 'ashes']; LogProb = -53.19461236634763
# Reversed MaxMatch = ['#', 'p', 'matt', 'he', 'ashes']; LogProb = -50.79748853317951
#
# 61. #blogtourambiente
# MaxMatch = ['#', 'blo', 'g', 'tour', 'ambient', 'e']; LogProb = -73.71080177251329
# Reversed MaxMatch = ['#', 'blo', 'g', 'tour', 'ambient', 'e']; LogProb = -89.10863440692928
#
# 62. #skeemsaam
# MaxMatch = ['#', 'skee', 'ms', 'aam']; LogProb = -54.92923892279327
# Reversed MaxMatch = ['#', 'skee', 'ms', 'aam']; LogProb = -74.79481526176023
#
# 63. #surfshop
# MaxMatch = ['#', 'surfs', 'hop']; LogProb = -40.92227611992792
# Reversed MaxMatch = ['#', 'surfs', 'hop']; LogProb = -37.16885814467641
#
# 64. #grandmarnier
# MaxMatch = ['#', 'grandma', 'r', 'ni', 'er']; LogProb = -63.73219503858182
# Reversed MaxMatch = ['#', 'grandma', 'r', 'ni', 'er']; LogProb = -63.30978037215988
#
# 65. #nickryrie
# MaxMatch = ['#', 'nick', 'r', 'yr', 'ie']; LogProb = -63.1131558301756
# Reversed MaxMatch = ['#', 'nick', 'r', 'yr', 'ie']; LogProb = -61.321396360947546
#
# 66. #thevoiceau
# MaxMatch = ['#', 'the', 'voice', 'a', 'u']; LogProb = -40.76322109722357
# Reversed MaxMatch = ['#', 'the', 'voice', 'a', 'u']; LogProb = -78.27907184983081
#
# 67. #blessedsunday
# MaxMatch = ['#', 'blesseds', 'un', 'day']; LogProb = -46.855005043912776
# Reversed MaxMatch = ['#', 'blesseds', 'un', 'day']; LogProb = -34.7568582656965
#
# 68. #hometomama
# MaxMatch = ['#', 'home', 'toma', 'ma']; LogProb = -46.72584365095937
# Reversed MaxMatch = ['#', 'home', 'toma', 'ma']; LogProb = -44.869545660593744
#
# 69. #happybirthdaysandarapark
# MaxMatch = ['#', 'happy', 'birthdays', 'anda', 'rap', 'ark']; LogProb = -78.34804467838937
# Reversed MaxMatch = ['#', 'happy', 'birthdays', 'anda', 'rap', 'ark']; LogProb = -68.58104526630402
#
# 70. #palacefansinthemorning
# MaxMatch = ['#', 'palace', 'fans', 'in', 'them', 'or', 'ning']; LogProb = -65.4919735537188
# Reversed MaxMatch = ['#', 'palace', 'fans', 'in', 'them', 'or', 'ning']; LogProb = -56.93235542964953
#
# 71. #vegan
# MaxMatch = ['#', 'vega', 'n']; LogProb = -38.357326762466386
# Reversed MaxMatch = ['#', 'vega', 'n']; LogProb = -48.98207463458186
#
# 72. #askherforfback
# MaxMatch = ['#', 'ask', 'her', 'for', 'f', 'back']; LogProb = -51.52022864808315
# Reversed MaxMatch = ['#', 'ask', 'her', 'for', 'f', 'back']; LogProb = -60.67822253968713
#
# 73. #takeabreak
# MaxMatch = ['#', 'take', 'ab', 'reak']; LogProb = -48.22645989116989
# Reversed MaxMatch = ['#', 'take', 'ab', 'reak']; LogProb = -51.53921484172923
#
# 74. #cumannanya
# MaxMatch = ['#', 'cum', 'anna', 'n', 'ya']; LogProb = -62.68237291408313
# Reversed MaxMatch = ['#', 'cum', 'anna', 'n', 'ya']; LogProb = -60.9822977275441
#
# 75. #beringmy
# MaxMatch = ['#', 'beri', 'n', 'g', 'my']; LogProb = -56.353409871423544
# Reversed MaxMatch = ['#', 'beri', 'n', 'g', 'my']; LogProb = -36.21141120026617
#
# 76. #peperoni
# MaxMatch = ['#', 'pep', 'er', 'on', 'i']; LogProb = -52.66904173697897
# Reversed MaxMatch = ['#', 'pep', 'er', 'on', 'i']; LogProb = -66.32124194762241
#
# 77. #strictlyus
# MaxMatch = ['#', 'strictly', 'us']; LogProb = -31.978334807936903
# Reversed MaxMatch = ['#', 'strictly', 'us']; LogProb = -50.70973121761716
#
# 78. #veganfood
# MaxMatch = ['#', 'vega', 'n', 'food']; LogProb = -47.36707729156761
# Reversed MaxMatch = ['#', 'vega', 'n', 'food']; LogProb = -57.99182516368309
#
# 79. #cornell
# MaxMatch = ['#', 'cornel', 'l']; LogProb = -39.18767506453982
# Reversed MaxMatch = ['#', 'cornel', 'l']; LogProb = -41.32774122803609
#
# 80. #thankyoupatients
# MaxMatch = ['#', 'thank', 'youp', 'ati', 'en', 'ts']; LogProb = -78.351417362868
# Reversed MaxMatch = ['#', 'thank', 'youp', 'ati', 'en', 'ts']; LogProb = -40.70828481250871
#
# 81. #google
# MaxMatch = ['#', 'goo', 'g', 'l', 'e']; LogProb = -60.65481525950998
# Reversed MaxMatch = ['#', 'goo', 'g', 'l', 'e']; LogProb = -35.579941867963115
#
# 82. #innoretail
# MaxMatch = ['#', 'inn', 'ore', 'tail']; LogProb = -50.506390293599125
# Reversed MaxMatch = ['#', 'inn', 'ore', 'tail']; LogProb = -35.34652286597065
#
# 83. #shopaholic
# MaxMatch = ['#', 'shop', 'aho', 'li', 'c']; LogProb = -61.0719098862338
# Reversed MaxMatch = ['#', 'shop', 'aho', 'li', 'c']; LogProb = -65.23079296959347
#
# 84. #jrsurfboards
# MaxMatch = ['#', 'j', 'rs', 'urf', 'boards']; LogProb = -64.21770285436352
# Reversed MaxMatch = ['#', 'j', 'rs', 'urf', 'boards']; LogProb = -50.41837941627642
#
# 85. #singapore
# MaxMatch = ['#', 'sing', 'a', 'pore']; LogProb = -41.32215573230752
# Reversed MaxMatch = ['#', 'sing', 'a', 'pore']; LogProb = -51.79374470686412
#
# 86. #1stsundayofoctober
# MaxMatch = ['#', '1', 'st', 'sunday', 'ofo', 'c', 'tobe', 'r']; LogProb = -92.69405063506932
# Reversed MaxMatch = ['#', '1', 'st', 'sunday', 'ofo', 'c', 'tobe', 'r']; LogProb = -58.69378286889845
#
# 87. #startuphub
# MaxMatch = ['#', 'start', 'up', 'hub']; LogProb = -40.954658376095665
# Reversed MaxMatch = ['#', 'start', 'up', 'hub']; LogProb = -50.2848480236519
#
# 88. #southampton
# MaxMatch = ['#', 'south', 'am', 'p', 'ton']; LogProb = -52.09488365569565
# Reversed MaxMatch = ['#', 'south', 'am', 'p', 'ton']; LogProb = -63.278947787283734
#
# 89. #instagood
# MaxMatch = ['#', 'ins', 'tag', 'o', 'od']; LogProb = -64.94721767909434
# Reversed MaxMatch = ['#', 'ins', 'tag', 'o', 'od']; LogProb = -49.33452754319143
#
# 90. #laundryservice
# MaxMatch = ['#', 'laundrys', 'er', 'vice']; LogProb = -52.290181593178005
# Reversed MaxMatch = ['#', 'laundrys', 'er', 'vice']; LogProb = -34.47338672578107
#
# 91. #arte
# MaxMatch = ['#', 'art', 'e']; LogProb = -32.96498208992691
# Reversed MaxMatch = ['#', 'art', 'e']; LogProb = -42.02088840859603
#
# 92. #rainorshine
# MaxMatch = ['#', 'rain', 'ors', 'hin', 'e']; LogProb = -62.0585620705811
# Reversed MaxMatch = ['#', 'rain', 'ors', 'hin', 'e']; LogProb = -58.60823105917856
#
# 93. #uptonogood
# MaxMatch = ['#', 'up', 'ton', 'og', 'o', 'od']; LogProb = -70.56202155291402
# Reversed MaxMatch = ['#', 'up', 'ton', 'og', 'o', 'od']; LogProb = -37.95611959084162
#
# 94. #1yearofalmostisneverenough
# MaxMatch = ['#', '1', 'year', 'of', 'almost', 'is', 'never', 'enough']; LogProb = -60.88685623910921
# Reversed MaxMatch = ['#', '1', 'year', 'of', 'almost', 'is', 'never', 'enough']; LogProb = -86.92774054397007
#
# 95. #meetup
# MaxMatch = ['#', 'meet', 'up']; LogProb = -29.465392045841316
# Reversed MaxMatch = ['#', 'meet', 'up']; LogProb = -45.239315946791024
#
# 96. #excitables
# MaxMatch = ['#', 'excitable', 's']; LogProb = -38.88539419266688
# Reversed MaxMatch = ['#', 'excitable', 's']; LogProb = -51.77585780960129
#
# 97. #makeupfree
# MaxMatch = ['#', 'make', 'up', 'free']; LogProb = -36.24396639713306
# Reversed MaxMatch = ['#', 'make', 'up', 'free']; LogProb = -47.47143730689186
#
# 98. #ariona
# MaxMatch = ['#', 'arion', 'a']; LogProb = -31.969153279599702
# Reversed MaxMatch = ['#', 'arion', 'a']; LogProb = -47.47819082990764
#
# 99. #brooksengland
# MaxMatch = ['#', 'brooks', 'en', 'gland']; LogProb = -48.81261123273127
# Reversed MaxMatch = ['#', 'brooks', 'en', 'gland']; LogProb = -52.33897175734744
#
# 100. #ladygaga
# MaxMatch = ['#', 'lady', 'gag', 'a']; LogProb = -39.9722290153585
# Reversed MaxMatch = ['#', 'lady', 'gag', 'a']; LogProb = -48.80018871273272
#
# 101. #olah
# MaxMatch = ['#', 'o', 'la', 'h']; LogProb = -45.58366860155698
# Reversed MaxMatch = ['#', 'o', 'la', 'h']; LogProb = -46.763306785471684
#
# 102. #magazinesandtvscreens
# MaxMatch = ['#', 'magazines', 'and', 't', 'vs', 'creen', 's']; LogProb = -75.41899821647736
# Reversed MaxMatch = ['#', 'magazines', 'and', 't', 'vs', 'creen', 's']; LogProb = -66.89879292342849
#
# 103. #8thannualpubcrawl
# MaxMatch = ['#', '8', 'than', 'nu', 'alp', 'u', 'b', 'crawl']; LogProb = -90.10494111288482
# Reversed MaxMatch = ['#', '8', 'than', 'nu', 'alp', 'u', 'b', 'crawl']; LogProb = -71.6475993701122
#
# 104. #allwedoiscurls
# MaxMatch = ['#', 'all', 'wed', 'o', 'is', 'curls']; LogProb = -61.72586615775175
# Reversed MaxMatch = ['#', 'all', 'wed', 'o', 'is', 'curls']; LogProb = -64.32855584319614
#
# 105. #potd
# MaxMatch = ['#', 'pot', 'd']; LogProb = -34.72176694588523
# Reversed MaxMatch = ['#', 'pot', 'd']; LogProb = -41.32774122803609
#
# 106. #booyaa
# MaxMatch = ['#', 'boo', 'ya', 'a']; LogProb = -43.673530989471
# Reversed MaxMatch = ['#', 'boo', 'ya', 'a']; LogProb = -52.84979738111343
#
# 107. #usydoweek
# MaxMatch = ['#', 'us', 'y', 'dow', 'e', 'e', 'k']; LogProb = -78.30630975614531
# Reversed MaxMatch = ['#', 'us', 'y', 'dow', 'e', 'e', 'k']; LogProb = -48.888283764935146
#
# 108. #flambees
# MaxMatch = ['#', 'flamb', 'e', 'es']; LogProb = -52.314279144757066
# Reversed MaxMatch = ['#', 'flamb', 'e', 'es']; LogProb = -39.24829968635625
#
# 109. #loadsoffun
# MaxMatch = ['#', 'loads', 'off', 'un']; LogProb = -44.52943043269403
# Reversed MaxMatch = ['#', 'loads', 'off', 'un']; LogProb = -39.32061231617104
#
# 110. #toronto
# MaxMatch = ['#', 'toro', 'n', 'to']; LogProb = -42.19234098679093
# Reversed MaxMatch = ['#', 'toro', 'n', 'to']; LogProb = -37.91001454442272
#
# 111. #statoftheday
# MaxMatch = ['#', 'st', 'at', 'oft', 'he', 'day']; LogProb = -59.061507392019756
# Reversed MaxMatch = ['#', 'st', 'at', 'oft', 'he', 'day']; LogProb = -52.02081500903782
#
# 112. #seniorbabysenior
# MaxMatch = ['#', 'senior', 'babys', 'en', 'io', 'r']; LogProb = -74.05027838733322
# Reversed MaxMatch = ['#', 'senior', 'babys', 'en', 'io', 'r']; LogProb = -44.77402036209102
#
# 113. #mamajeanneandme
# MaxMatch = ['#', 'mam', 'a', 'jeanne', 'and', 'me']; LogProb = -56.645074579723975
# Reversed MaxMatch = ['#', 'mam', 'a', 'jeanne', 'and', 'me']; LogProb = -63.17044918410414
#
# 114. #isibaya
# MaxMatch = ['#', 'is', 'iba', 'ya']; LogProb = -45.19713298701276
# Reversed MaxMatch = ['#', 'is', 'iba', 'ya']; LogProb = -46.78504364934769
#
# 115. #goingout
# MaxMatch = ['#', 'going', 'out']; LogProb = -28.380684072531803
# Reversed MaxMatch = ['#', 'going', 'out']; LogProb = -38.52004758240894
#
# 116. #blessedmorethanicanimagine
# MaxMatch = ['#', 'blessed', 'more', 'than', 'i', 'can', 'imagine']; LogProb = -60.058470767841214
# Reversed MaxMatch = ['#', 'blessed', 'more', 'than', 'i', 'can', 'imagine']; LogProb = -75.00004826278757
#
# 117. #pechanga
# MaxMatch = ['#', 'pech', 'an', 'ga']; LogProb = -47.107595796553284
# Reversed MaxMatch = ['#', 'pech', 'an', 'ga']; LogProb = -47.970473722903385
#
# 118. #fotorus
# MaxMatch = ['#', 'fot', 'or', 'us']; LogProb = -41.16715305182789
# Reversed MaxMatch = ['#', 'fot', 'or', 'us']; LogProb = -42.02088840859603
#
# 119. #ididntchoosethestudentlifeitchoseme
# MaxMatch = ['#', 'id', 'id', 'n', 'tch', 'o', 'ose', 'the', 'student', 'life', 'itch', 'ose', 'me']; LogProb = -143.6520627273642
# Reversed MaxMatch = ['#', 'id', 'id', 'n', 'tch', 'o', 'ose', 'the', 'student', 'life', 'itch', 'ose', 'me']; LogProb = -95.89774415115184
#
# 120. #mtlnewtech
# MaxMatch = ['#', 'm', 't', 'l', 'newt', 'e', 'c', 'h']; LogProb = -88.13969538899899
# Reversed MaxMatch = ['#', 'm', 't', 'l', 'newt', 'e', 'c', 'h']; LogProb = -64.42140720789112
#
# 121. #datingsiteforyou
# MaxMatch = ['#', 'datings', 'it', 'e', 'for', 'you']; LogProb = -53.9944149525532
# Reversed MaxMatch = ['#', 'datings', 'it', 'e', 'for', 'you']; LogProb = -46.99526436672879
#
# 122. #anferneehardaway
# MaxMatch = ['#', 'an', 'fern', 'e', 'eh', 'ar', 'daw', 'ay']; LogProb = -97.22465036397413
# Reversed MaxMatch = ['#', 'an', 'fern', 'e', 'eh', 'ar', 'daw', 'ay']; LogProb = -74.77282410312905
#
# 123. #bettybooppose
# MaxMatch = ['#', 'betty', 'boo', 'p', 'pose']; LogProb = -61.126660401005196
# Reversed MaxMatch = ['#', 'betty', 'boo', 'p', 'pose']; LogProb = -51.17582094754176
#
# 124. #bedimages
# MaxMatch = ['#', 'bedim', 'ages']; LogProb = -38.069644690014606
# Reversed MaxMatch = ['#', 'bedim', 'ages']; LogProb = -33.53127198495003

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict the country of origin of a given tweet. The task here is to create training, development and test partitions from the preprocessed data (`x_processed`) and convert the bag-of-words representation into feature vectors.
#
# **Task**: Create training, development and test partitions with a 70%/15%/15% ratio. Remember to preserve the ratio of the classes for all your partitions. That is, say we have only 2 classes and 70% of instances are labelled class A and 30% of instances are labelled class B, then the instances in training, development and test partitions should also preserve this 7:3 ratio. You may use sklearn's builtin functions for doing data partitioning.
#
# Next, turn the bag-of-words dictionary of each tweet into a feature vector. You may also use sklearn's builtin functions for doing this (but if you don't want to use sklearn that's fine).
#
# You should produce 6 objects: `x_train`, `x_dev`, `x_test` which contain the input feature vectors, and `y_train`, `y_dev` and `y_test` which contain the labels.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
x_train, x_dev, x_test = None, None, None
y_train, y_dev, y_test = None, None, None

###
# Your answer BEGINS HERE
###
# x_processed, y_processed
x_train, x_test_dev, y_train, y_test_dev = train_test_split(x_processed, y_processed, train_size = 0.7, test_size=0.3, random_state=123, stratify = y_processed)

# get dev and test sets 
x_dev, x_test, y_dev, y_test = train_test_split(x_test_dev, y_test_dev, train_size = 0.5, test_size=0.5, random_state=123, stratify = y_test_dev)

dict_vectorizer = DictVectorizer()
x_train = dict_vectorizer.fit_transform(x_train)
x_dev = dict_vectorizer.transform(x_dev)
x_test = dict_vectorizer.transform(x_test)

###
# Your answer ENDS HERE
###

# %% [markdown]
# ### Question 6 (1.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation hyper-parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the **accuracy** with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output.
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance (accuracy) for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import operator

###
# Your answer BEGINS HERE
###

# tuning NB hyper_parameters

# NB_classifier.get_params()
alpha = [1,0.1,0.01,0.001, 0.0001, 0.00001, 0.000001]
fit_prior = [False, True]
print("Tuning for NB classifier")
NB_tunning_dict = {}
for a in alpha:
    for f in fit_prior:
        NB_classifier = MultinomialNB(alpha=a, fit_prior = f)
        NB_classifier.fit(x_train, y_train)
        y_pred_NB = NB_classifier.predict(x_dev)
        accuracy_NB = metrics.accuracy_score(y_dev, y_pred_NB)
        # get json string of parameters
        param_comb = json.dumps({'alpha' :a , "fit_prior": f})
        # hash dict parameter json string and accuracy
        NB_tunning_dict[param_comb] = accuracy_NB
        print("Accuracy NB:", accuracy_NB, ", with params: ", param_comb)
print(
    'Best NB params: ' + max(NB_tunning_dict.items(), key=operator.itemgetter(1))[0],
    ', with accuracy: '+ str(max(NB_tunning_dict.items(), key=operator.itemgetter(1))[1])
    )
    
# tuning LR hyper_parameters
C = [1000, 100, 10, 1.0, 0.1, 0.01, 0.001]
solver = ['newton-cg', 'lbfgs', 'liblinear']
print("Tuning for LR classifier")
LR_tunning_dict = {}
for c in C:
    for s in solver:
        LR_classifier = LogisticRegression(C=c, solver = s)
        LR_classifier.fit(x_train, y_train)
        y_pred_LR = LR_classifier.predict(x_dev)
        accuracy_LR = metrics.accuracy_score(y_dev, y_pred_LR)
        # get json string of parameters
        param_comb = json.dumps({'C' :c , "solver": s})
        # hash dict parameter json string and accuracy
        LR_tunning_dict[param_comb] = accuracy_LR
        print("Accuracy LR:", accuracy_LR, ", with params: ", param_comb)
print(
    'Best LR params: ' + max(LR_tunning_dict.items(), key=operator.itemgetter(1))[0],
    ', with accuracy: '+ str(max(LR_tunning_dict.items(), key=operator.itemgetter(1))[1])
    )


###
# Your answer ENDS HERE
###
# Out:
# Tuning for NB classifier
# Accuracy NB: 0.3191489361702128 , with params:  {"alpha": 1, "fit_prior": false}
# Accuracy NB: 0.3120567375886525 , with params:  {"alpha": 1, "fit_prior": true}
# Accuracy NB: 0.3333333333333333 , with params:  {"alpha": 0.1, "fit_prior": false}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 0.1, "fit_prior": true}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 0.01, "fit_prior": false}
# Accuracy NB: 0.3191489361702128 , with params:  {"alpha": 0.01, "fit_prior": true}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 0.001, "fit_prior": false}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 0.001, "fit_prior": true}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 0.0001, "fit_prior": false}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 0.0001, "fit_prior": true}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 1e-05, "fit_prior": false}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 1e-05, "fit_prior": true}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 1e-06, "fit_prior": false}
# Accuracy NB: 0.3262411347517731 , with params:  {"alpha": 1e-06, "fit_prior": true}
# Best NB params: {"alpha": 0.1, "fit_prior": false} , with accuracy: 0.3333333333333333
# Tuning for LR classifier
# Accuracy LR: 0.2978723404255319 , with params:  {"C": 1000, "solver": "newton-cg"}
# Accuracy LR: 0.2978723404255319 , with params:  {"C": 1000, "solver": "lbfgs"}
# Accuracy LR: 0.3049645390070922 , with params:  {"C": 1000, "solver": "liblinear"}
# Accuracy LR: 0.3049645390070922 , with params:  {"C": 100, "solver": "newton-cg"}
# Accuracy LR: 0.3049645390070922 , with params:  {"C": 100, "solver": "lbfgs"}
# Accuracy LR: 0.3049645390070922 , with params:  {"C": 100, "solver": "liblinear"}
# Accuracy LR: 0.3049645390070922 , with params:  {"C": 10, "solver": "newton-cg"}
# Accuracy LR: 0.3049645390070922 , with params:  {"C": 10, "solver": "lbfgs"}
# Accuracy LR: 0.2978723404255319 , with params:  {"C": 10, "solver": "liblinear"}
# Accuracy LR: 0.3120567375886525 , with params:  {"C": 1.0, "solver": "newton-cg"}
# Accuracy LR: 0.3120567375886525 , with params:  {"C": 1.0, "solver": "lbfgs"}
# Accuracy LR: 0.3120567375886525 , with params:  {"C": 1.0, "solver": "liblinear"}
# Accuracy LR: 0.3191489361702128 , with params:  {"C": 0.1, "solver": "newton-cg"}
# Accuracy LR: 0.3191489361702128 , with params:  {"C": 0.1, "solver": "lbfgs"}
# Accuracy LR: 0.3191489361702128 , with params:  {"C": 0.1, "solver": "liblinear"}
# Accuracy LR: 0.2765957446808511 , with params:  {"C": 0.01, "solver": "newton-cg"}
# Accuracy LR: 0.2765957446808511 , with params:  {"C": 0.01, "solver": "lbfgs"}
# Accuracy LR: 0.3049645390070922 , with params:  {"C": 0.01, "solver": "liblinear"}
# Accuracy LR: 0.2765957446808511 , with params:  {"C": 0.001, "solver": "newton-cg"}
# Accuracy LR: 0.2765957446808511 , with params:  {"C": 0.001, "solver": "lbfgs"}
# Accuracy LR: 0.2978723404255319 , with params:  {"C": 0.001, "solver": "liblinear"}
# Best LR params: {"C": 0.1, "solver": "newton-cg"} , with accuracy: 0.3191489361702128

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both **accuracy** and **macro-averaged F-score** for each classifier. Be sure to label your output. You may use sklearn's inbuilt functions.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using their optimal hyper-parameter settings based on their development performance.

# %%
###
# Your answer BEGINS HERE
###
from sklearn import metrics

# NB classifier, using best parameters produced in Question 6
print("------------------Naive Bayes---------------------")
# load param json from dict key
best_param_NB = json.loads(max(NB_tunning_dict.items(), key=operator.itemgetter(1))[0])
NB_classifier = MultinomialNB(alpha = best_param_NB['alpha'], fit_prior = best_param_NB['fit_prior'])
NB_classifier.fit(x_train, y_train) 
y_pred_NB = NB_classifier.predict(x_test) 
acc_NB = metrics.accuracy_score(y_test, y_pred_NB)
f1_macro_NB = metrics.f1_score(y_test, y_pred_NB, average='macro')
print('Parameters: ', best_param_NB)
print('Naive Bayes accuracy:', acc_NB)
print('Naive Bayes macro F1-score:', f1_macro_NB, '\n')

# LR classifier, using best parameters produced in Question 6
print("------------------Logistic regression---------------------")
# load param json from dict key
best_param_LR = json.loads(max(LR_tunning_dict.items(), key=operator.itemgetter(1))[0])
LR_classifier = LogisticRegression(C = best_param_LR['C'], solver= best_param_LR['solver'])
LR_classifier.fit(x_train, y_train) 
y_pred_LR = LR_classifier.predict(x_test) 
acc_LR = metrics.accuracy_score(y_test, y_pred_LR)
f1_macro_LR = metrics.f1_score(y_test, y_pred_LR, average='macro')
print('Parameters: ', best_param_LR)
print('Logistic regression accuracy:', acc_LR)
print('Logistic regression macro F1-score:', f1_macro_LR, '\n')


###
# Your answer ENDS HERE
###
# Out:
# ------------------Naive Bayes---------------------
# Parameters:  {'alpha': 0.1, 'fit_prior': False}
# Naive Bayes accuracy: 0.30985915492957744
# Naive Bayes macro F1-score: 0.29593664890043014
#
# ------------------Logistic regression---------------------
# Parameters:  {'C': 0.1, 'solver': 'newton-cg'}
# Logistic regression accuracy: 0.30985915492957744
# Logistic regression macro F1-score: 0.27526550153325

# %% [markdown]
# ### Question 8 (1.0 mark)
#
# **Instructions**: Print the most important features and their weights for each class for the two classifiers.
#
#
# **Task**: For each of the classifiers (Logistic Regression and Naive Bayes) you've built in the previous question, print out the top-20 features (words) with the highest weight for each class (countries).
#
# An example output:
# ```
# Classifier = Logistic Regression
#
# Country = au
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Country = ca
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Classifier = Naive Bayes
#
# Country = au
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
#
# Country = ca
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
# ```
#
# Have a look at the output, and see if you notice any trend/pattern in the words for each country.

# %%
###
# Your answer BEGINS HERE
###
print("Classifier = Logistic Regression\n")
feature_names = dict_vectorizer.get_feature_names()
class_LR = LR_classifier.classes_
feature_coef_LR = LR_classifier.coef_

for i in range(len(class_LR)):
    print("Country =", class_LR[i])
    prob_feature_names = sorted(zip(feature_coef_LR[i], feature_names), reverse=True)
    output_str = ''
    for j in range(20):
        output_str = output_str + prob_feature_names[j][1] + ' (' +  str(round(prob_feature_names[j][0],3)) + ') ' 
    print(output_str)
    print()

print("Classifier = Naive Bayes\n")
feature_names = dict_vectorizer.get_feature_names()
class_NB = NB_classifier.classes_
feature_probs_NB = NB_classifier.feature_log_prob_

for i in range(len(class_NB)):
    print("Country =", class_NB[i])
    prob_feature_names = sorted(zip(feature_probs_NB[i], feature_names), reverse=True)
    output_str = ''
    for j in range(20):
        output_str = output_str + prob_feature_names[j][1] + ' (' +  str(round(prob_feature_names[j][0],3)) + ') ' 
    print(output_str)
    print()




###
# Your answer ENDS HERE
###
# Out:
# Classifier = Logistic Regression
#
# Country = au
# melbourne (0.403) great (0.252) australia (0.232) keep (0.198) one (0.195) @micksunnyg (0.166) #melbourne (0.164) australian (0.162) power (0.158) shows (0.155) even (0.155) #photography (0.154) little (0.151) name (0.151) cry (0.15) #affsuzukicup (0.15) green (0.149) tomorrow (0.148) finished (0.146) sledging (0.143)
#
# Country = ca
# thing (0.276) great (0.252) maybe (0.245) one (0.213) got (0.19) school (0.19) first (0.173) may (0.172) happen (0.168) finally (0.16) sounds (0.159) going (0.158) healthy (0.157) actually (0.157) next (0.152) bus (0.149) rd (0.148) pumper (0.148) ny (0.148) #photo (0.148)
#
# Country = de
# posted (0.293) photo (0.198) enough (0.173) factory (0.173) #rosegold (0.17) painting (0.166) almost (0.165) germany (0.163) tages (0.156) medinger (0.156) markus (0.156) https://t.co/dpfrjtdarl (0.156) des (0.156) bild (0.156) #mkmedi (0.156) miss (0.139) picture (0.137) night (0.128) please (0.128) come (0.12)
#
# Country = gb
# x (0.499) got (0.25) sure (0.24) well (0.216) always (0.206) yeah (0.204) that's (0.175) chelsea (0.165) stressed (0.164) seeing (0.162) back (0.162) liverpool (0.161) @skyhelpteam (0.157) season (0.155) xx (0.154) team (0.152) looks (0.148) golf (0.147) glad (0.142) though (0.142)
#
# Country = id
# pic (0.624) hiks (0.208) cafe (0.204) others (0.2) overboard (0.164) ini (0.154) karaoke (0.153) donuts (0.152) shaw (0.146) mikleo (0.145) bagus (0.145) kerja (0.144) keras (0.144) senayan (0.144) coffee (0.143) ga (0.141) banget (0.141) justin (0.139) bieber (0.139) #hollywoodmusicawards (0.139)
#
# Country = my
# i'm (0.465) selangor (0.311) ni (0.294) thank (0.266) lumpur (0.265) kuala (0.265) nk (0.249) jaya (0.243) birthday (0.206) cendol (0.2) take (0.195) subang (0.177) @poemporns (0.173) kl (0.168) johor (0.164) lagi (0.162) badminton (0.158) beb (0.157) tiktok (0.155) allah (0.153)
#
# Country = ph
# follow (0.452) please (0.362) city (0.326) sm (0.256) manila (0.242) im (0.226) ng (0.226) ka (0.206) yesterday (0.2) mo (0.191) dis (0.19) back (0.181) gonna (0.168) good (0.166) dreams (0.163) @iam3l (0.163) #hometomama (0.163) yet (0.162) sight (0.162) hideout (0.159)
#
# Country = sg
# singapore (0.518) use (0.233) w (0.227) batam (0.226) park (0.2) work (0.184) see (0.178) say (0.171) @tutiandonlyher (0.171) fitness (0.163) keri (0.162) @weichen_7 (0.161) hang (0.157) far (0.156) resort (0.156) food (0.156) watching (0.154) kau (0.148) others (0.144) east (0.143)
#
# Country = us
# like (0.321) ever (0.28) get (0.258) beer (0.221) still (0.208) feel (0.19) true (0.182) beginning (0.16) texas (0.156) sick (0.155) #allcity (0.154) house (0.15) gym (0.15) every (0.144) i'll (0.144) find (0.14) @tushposhboss (0.136) hopefully (0.131) better (0.13) tonight (0.124)
#
# Country = za
# u (0.32) day (0.249) good (0.238) man (0.232) happy (0.217) ur (0.204) love (0.204) everything (0.194) feel (0.192) that's (0.18) something (0.179) better (0.179) got (0.178) time (0.175) today (0.172) close (0.164) yebo (0.16) south (0.157) africa (0.157) gig (0.156)
#
# Classifier = Naive Bayes
#
# Country = au
# melbourne (-4.951) i'm (-4.951) one (-5.13) great (-5.13) make (-5.628) keep (-5.628) get (-5.628) even (-5.628) australia (-5.628) want (-6.017) visit (-6.017) vca (-6.017) two (-6.017) tomorrow (-6.017) song (-6.017) sledging (-6.017) shows (-6.017) pretty (-6.017) power (-6.017) name (-6.017)
#
# Country = ca
# one (-5.171) maybe (-5.171) great (-5.171) thing (-5.389) i'm (-5.389) got (-5.389) today (-5.669) time (-5.669) thanks (-5.669) school (-5.669) next (-5.669) new (-5.669) may (-5.669) like (-5.669) going (-5.669) first (-5.669) year (-6.058) would (-6.058) way (-6.058) want (-6.058)
#
# Country = de
# posted (-4.97) photo (-5.25) i'm (-5.25) tages (-5.64) please (-5.64) picture (-5.64) painting (-5.64) night (-5.64) miss (-5.64) medinger (-5.64) markus (-5.64) love (-5.64) https://t.co/dpfrjtdarl (-5.64) good (-5.64) germany (-5.64) factory (-5.64) enough (-5.64) des (-5.64) day (-5.64) come (-5.64)
#
# Country = gb
# x (-4.785) got (-5.116) sure (-5.334) i'm (-5.334) yeah (-5.614) well (-5.614) that's (-5.614) right (-5.614) new (-5.614) get (-5.614) day (-5.614) back (-5.614) always (-5.614) xx (-6.003) work (-6.003) wish (-6.003) us (-6.003) u (-6.003) today (-6.003) though (-6.003)
#
# Country = id
# pic (-4.332) i'm (-5.016) others (-5.234) posted (-5.513) photo (-5.513) hiks (-5.513) haha (-5.513) cafe (-5.513) world (-5.903) way (-5.903) w (-5.903) sorry (-5.903) shaw (-5.903) senayan (-5.903) rt (-5.903) room (-5.903) right (-5.903) overboard (-5.903) one (-5.903) night (-5.903)
#
# Country = my
# i'm (-4.059) w (-5.076) selangor (-5.076) happy (-5.076) thank (-5.294) nk (-5.294) ni (-5.294) lumpur (-5.294) kuala (-5.294) jaya (-5.294) birthday (-5.294) u (-5.574) time (-5.574) take (-5.574) subang (-5.574) maybe (-5.574) haha (-5.574) cendol (-5.574) world (-5.963) way (-5.963)
#
# Country = ph
# follow (-4.623) please (-4.755) city (-5.086) w (-5.304) sm (-5.304) manila (-5.304) make (-5.304) like (-5.304) im (-5.304) i'm (-5.304) good (-5.304) yesterday (-5.584) year (-5.584) true (-5.584) others (-5.584) ng (-5.584) mo (-5.584) ka (-5.584) gonna (-5.584) dreams (-5.584)
#
# Country = sg
# singapore (-4.687) w (-5.018) i'm (-5.018) work (-5.516) use (-5.516) see (-5.516) say (-5.516) park (-5.516) others (-5.516) make (-5.516) good (-5.516) batam (-5.516) wkwkwkwk (-5.905) watching (-5.905) want (-5.905) thanks (-5.905) side (-5.905) resort (-5.905) pic (-5.905) perfect (-5.905)
#
# Country = us
# like (-4.733) get (-5.064) i'm (-5.282) ever (-5.282) u (-5.562) true (-5.562) still (-5.562) new (-5.562) make (-5.562) love (-5.562) house (-5.562) happy (-5.562) feel (-5.562) beer (-5.562) year (-5.951) would (-5.951) we're (-5.951) tonight (-5.951) today (-5.951) time (-5.951)
#
# Country = za
# u (-4.947) happy (-4.947) love (-5.126) good (-5.126) day (-5.126) today (-5.345) time (-5.345) like (-5.345) got (-5.345) ur (-5.624) that's (-5.624) something (-5.624) one (-5.624) next (-5.624) man (-5.624) feel (-5.624) everything (-5.624) better (-5.624) yebo (-6.014) way (-6.014)
